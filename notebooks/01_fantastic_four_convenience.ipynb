# %% [markdown]
# # EXCEED Prolific Study: Finding the Fantastic Four - Convenience Sampling
#
# Within this notebook, we will analyze the results of our pilot study where we asked participants to go over 8 different Python buggy code snippets, and their associated standard interpreter error messages, and provide ratings on a 1-5 scale for several statements, namely:
# - "_This code snippet is difficult to understand._"
# - "_I would find it challenging to resolve the issue in this code snippet._"
# - "_Reading this error message feels mentally demanding._"
# - "_This error message is useful for identifying the problem._"
#
# The goal of this analysis isn't to necessarily find a "best" or "worst" error message (and code snippet), but rather to identify the four Python code snippets and their associated error messages that we will later use within the actual main Prolific study. We will refer to these as the "Fantastic Four".
#
# In this notebook we will analyze the results of the pilot study to identify the "Fantastic Four" snippets. The data within this section was collected from participants who were recruited via convenient sampling, meaning that they were not randomly selected but rather self-selected to participate in the study. This may introduce some bias in the results, but it is a common practice in pilot studies to quickly gather initial feedback and insights.

# %% [markdown]
# ## Step 0: Install Required Python Libraries

# %%
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: pandas==2.2.3 in /Users/amoraru/Documents/GitHub/rag-qa-nlp14/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 1)) (2.2.3)
# Requirement already satisfied: ipython==9.2.0 in /Users/amoraru/Documents/GitHub/rag-qa-nlp14/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 2)) (9.2.0)
# Requirement already satisfied: Jinja2==3.1.6 in /Users/amoraru/Documents/GitHub/rag-qa-nlp14/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 3)) (3.1.6)
# Requirement already satisfied: numpy==2.2.6 in /Users/amoraru/Documents/GitHub/rag-qa-nlp14/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 4)) (2.2.6)
# Requirement already satisfied: scipy==1.15.3 in /Users/amoraru/Documents/GitHub/rag-qa-nlp14/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 5)) (1.15.3)
# Requirement already satisfied: matplotlib==3.10.3 in /Users/amoraru/Documents/GitHub/rag-qa-nlp14/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 6)) (3.10.3)
# Requirement already satisfied: seaborn==0.13.2 in /Users/amoraru/Documents/GitHub/rag-qa-nlp14/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 8)) (0.13.2)
# Requirement already satisfied: pandas-stubs==2.3.0.250703 in /Users/amoraru/Documents/GitHub/rag-qa-nlp14/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 9)) (2.3.0.250703)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/amoraru/Documents/GitHub/rag-qa-nlp14/.venv/lib/python3.12/site-packages (from pandas==2.2.3->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/amoraru/Documents/GitHub/rag-qa-nlp14/.venv/lib/python3.12/site-packages (from pandas==2.2.3->-r requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/amoraru/Documents/GitHub/rag-qa-nlp14/.venv/lib/python3.12/site-packages (from pandas==2.2.3->-r requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: decorator in /Users/amoraru/Documents/GitHub/rag-qa-nlp14/.venv/lib/python3.12/site-packages (from ipython==9.2.0->-r requirements.txt (line 2)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /Users/amoraru/Documents/GitHub/rag-qa-nlp14/.venv/lib/python3.12/site-packages (from ipython==9.2.0->-r requirements.txt (line 2)) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/amoraru/Documents/GitHub/rag-qa-nlp14/.venv/lib/python3.12/site-packages (from ipython==9.2.0->-r requirements.txt (line 2)) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /Users/amoraru/Documents/GitHub/rag-qa-nlp14/.venv/lib/python3.12/site-packages (from ipython==9.2.0->-r requirements.txt (line 2)) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /Users/amoraru/Documents/GitHub/rag-qa-nlp14/.venv/lib/python3.12/site-packages (from ipython==9.2.0->-r requirements.txt (line 2)) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/amoraru/Documents/GitHub/rag-qa-nlp14/.venv/lib/python3.12/site-packages (from ipython==9.2.0->-r requirements.txt (line 2)) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in /Users/amoraru/Documents/GitHub/rag-qa-nlp14/.venv/lib/python3.12/site-packages (from ipython==9.2.0->-r requirements.txt (line 2)) (2.19.2)
# Requirement already satisfied: stack_data in /Users/amoraru/Documents/GitHub/rag-qa-nlp14/.venv/lib/python3.12/site-packages (from ipython==9.2.0->-r requirements.txt (line 2)) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /Users/amoraru/Documents/GitHub/rag-qa-nlp14/.venv/lib/python3.12/site-packages (from ipython==9.2.0->-r requirements.txt (line 2)) (5.14.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/amoraru/Documents/GitHub/rag-qa-nlp14/.venv/lib/python3.12/site-packages (from Jinja2==3.1.6->-r requirements.txt (line 3)) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/amoraru/Documents/GitHub/rag-qa-nlp14/.venv/lib/python3.12/site-packages (from matplotlib==3.10.3->-r requirements.txt (line 6)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/amoraru/Documents/GitHub/rag-qa-nlp14/.venv/lib/python3.12/site-packages (from matplotlib==3.10.3->-r requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/amoraru/Documents/GitHub/rag-qa-nlp14/.venv/lib/python3.12/site-packages (from matplotlib==3.10.3->-r requirements.txt (line 6)) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/amoraru/Documents/GitHub/rag-qa-nlp14/.venv/lib/python3.12/site-packages (from matplotlib==3.10.3->-r requirements.txt (line 6)) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /Users/amoraru/Documents/GitHub/rag-qa-nlp14/.venv/lib/python3.12/site-packages (from matplotlib==3.10.3->-r requirements.txt (line 6)) (24.2)
# Requirement already satisfied: pillow>=8 in /Users/amoraru/Documents/GitHub/rag-qa-nlp14/.venv/lib/python3.12/site-packages (from matplotlib==3.10.3->-r requirements.txt (line 6)) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/amoraru/Documents/GitHub/rag-qa-nlp14/.venv/lib/python3.12/site-packages (from matplotlib==3.10.3->-r requirements.txt (line 6)) (3.2.3)
# Requirement already satisfied: types-pytz>=2022.1.1 in /Users/amoraru/Documents/GitHub/rag-qa-nlp14/.venv/lib/python3.12/site-packages (from pandas-stubs==2.3.0.250703->-r requirements.txt (line 9)) (2025.2.0.20250516)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/amoraru/Documents/GitHub/rag-qa-nlp14/.venv/lib/python3.12/site-packages (from jedi>=0.16->ipython==9.2.0->-r requirements.txt (line 2)) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/amoraru/Documents/GitHub/rag-qa-nlp14/.venv/lib/python3.12/site-packages (from pexpect>4.3->ipython==9.2.0->-r requirements.txt (line 2)) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/amoraru/Documents/GitHub/rag-qa-nlp14/.venv/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython==9.2.0->-r requirements.txt (line 2)) (0.2.13)
# Requirement already satisfied: six>=1.5 in /Users/amoraru/Documents/GitHub/rag-qa-nlp14/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas==2.2.3->-r requirements.txt (line 1)) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/amoraru/Documents/GitHub/rag-qa-nlp14/.venv/lib/python3.12/site-packages (from stack_data->ipython==9.2.0->-r requirements.txt (line 2)) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/amoraru/Documents/GitHub/rag-qa-nlp14/.venv/lib/python3.12/site-packages (from stack_data->ipython==9.2.0->-r requirements.txt (line 2)) (3.0.0)
# Requirement already satisfied: pure-eval in /Users/amoraru/Documents/GitHub/rag-qa-nlp14/.venv/lib/python3.12/site-packages (from stack_data->ipython==9.2.0->-r requirements.txt (line 2)) (0.2.3)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Step 1: Load the Data

# %%
import pandas as pd

# Set the path to the CSV file which contains the results of the pilot study
file_path = "../data/pilot_study_convenience_results.csv"

# Load the data into a DataFrame
df = pd.read_csv(file_path)

# Display the first few rows of the DataFrame
print("Displaying the first 5 rows of the DataFrame:")
df.head()
# Out:
# Displaying the first 5 rows of the DataFrame:
#                      Timestamp  This code snippet is difficult to understand.  \
# 0  2025/07/31 11:59:34 am EEST                                              1
# 1   2025/07/31 3:16:40 pm EEST                                              4
# 2  2025/08/01 11:27:09 am EEST                                              3
# 3   2025/08/01 6:34:41 pm EEST                                              2
# 4   2025/08/01 6:50:32 pm EEST                                              1
#
#    I would find it challenging to resolve the issue in this code snippet.  \
# 0                                                  1
# 1                                                  4
# 2                                                  1
# 3                                                  1
# 4                                                  2
#
#    Reading this error message feels mentally demanding.  \
# 0                                                  3
# 1                                                  4
# 2                                                  1
# 3                                                  3
# 4                                                  2
#
#    This error message is useful for identifying the problem.  \
# 0                                                  3
# 1                                                  2
# 2                                                  1
# 3                                                  4
# 4                                                  2
#
#    This code snippet is difficult to understand..1  \
# 0                                                3
# 1                                                2
# 2                                                3
# 3                                                1
# 4                                                1
#
#    I would find it challenging to resolve the issue in this code snippet..1  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
#    Reading this error message feels mentally demanding..1  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
#    This error message is useful for identifying the problem..1  \
# 0                                                  2
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  5
#
#    This code snippet is difficult to understand..2  ...  \
# 0                                                1  ...
# 1                                                1  ...
# 2                                                1  ...
# 3                                                1  ...
# 4                                                2  ...
#
#    Reading this error message feels mentally demanding..5  \
# 0                                                  2
# 1                                                  2
# 2                                                  1
# 3                                                  1
# 4                                                  2
#
#    This error message is useful for identifying the problem..5  \
# 0                                                  2
# 1                                                  2
# 2                                                  5
# 3                                                  5
# 4                                                  4
#
#    This code snippet is difficult to understand..6  \
# 0                                                2
# 1                                                1
# 2                                                1
# 3                                                1
# 4                                                1
#
#    I would find it challenging to resolve the issue in this code snippet..6  \
# 0                                                  3
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
#    Reading this error message feels mentally demanding..6  \
# 0                                                  3
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
#    This error message is useful for identifying the problem..6  \
# 0                                                  1
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  5
#
#    This code snippet is difficult to understand..7  \
# 0                                                2
# 1                                                4
# 2                                                1
# 3                                                1
# 4                                                3
#
#    I would find it challenging to resolve the issue in this code snippet..7  \
# 0                                                  3
# 1                                                  4
# 2                                                  1
# 3                                                  2
# 4                                                  4
#
#    Reading this error message feels mentally demanding..7  \
# 0                                                  3
# 1                                                  4
# 2                                                  1
# 3                                                  1
# 4                                                  4
#
#    This error message is useful for identifying the problem..7
# 0                                                  2
# 1                                                  2
# 2                                                  5
# 3                                                  5
# 4                                                  2
#
# [5 rows x 34 columns]

# %% [markdown]
# ## Step 2: Keep Only Rows with Attention Check Passed

# %%
# Define the column indices for each snippet
snippet_columns = {
    'snippet_1': list(range(1, 5)),
    'snippet_2': list(range(5, 9)),
    'snippet_3': list(range(9, 13)),
    'snippet_4': list(range(13, 18)),  # includes attention check
    'snippet_5': list(range(18, 22)),
    'snippet_6': list(range(22, 26)),
    'snippet_7': list(range(26, 30)),
    'snippet_8': list(range(30, 34)),
}

# Remove rows where the attention check failed (attention check column should be at index 16)
attention_check_col = df.columns[16]  # Get the actual column name at index 16

# Number of participants in the study before filtering
num_participants_before = len(df)
print(f"Number of participants before filtering for attention check: {num_participants_before}")

# Filter rows only where attention check is passed (5 means strongly agree)
filtered_df = df[df[attention_check_col] == 5]

# Number of participants in the study after filtering for attention check
num_participants_after = len(filtered_df)
print(f"Number of participants after filtering for attention check: {num_participants_after}")

# Adjust snippet_columns for snippet_4 to exclude the attention check column
snippet_columns_adjusted = snippet_columns.copy()
snippet_columns_adjusted['snippet_4'] = [13, 14, 15, 17]  # Exclude the attention check column (index 16)

# Extract questions and results for each snippet
snippets = {}
for key, cols in snippet_columns_adjusted.items():
    col_names = filtered_df.columns[cols]
    snippets[key] = filtered_df[col_names]
# Out:
# Number of participants before filtering for attention check: 14
# Number of participants after filtering for attention check: 14

# %% [markdown]
# ### Step 3: Analyze the Data
#
# In this step we will perform the following analyses:
# 1. Calculate the average ratings for each snippet for each question.
# 2. Rank the snippets based on their average ratings for each question.
# 3. Plot the average ratings for each snippet for each question.

# %% [markdown]
# ### Step 3.1: Calculate Average Ratings for Each Snippet For Each Question
#
# In this step, we will calculate the average ratings for each question across all snippets. This will help us understand how participants rated each snippet in terms of difficulty, challenge, mental demand, and usefulness of the error message. We will plot a bar chart for each question showing the average ratings for all snippets.

# %%
import matplotlib.pyplot as plt

# Plot histograms for each snippet and each question, with percentages on each bar
for snippet_name, snippet_df in snippets.items():
    for col in snippet_df.columns:
        plt.figure(figsize=(6, 4))
        data = snippet_df[col].dropna().astype(int)
        counts = data.value_counts().sort_index()
        total = counts.sum()
        bars = plt.bar(counts.index, counts.values, color='skyblue', edgecolor='black', align='center', width=0.6)
        plt.title(f"{snippet_name}: {col}")
        plt.xlabel("Response Value (1 = Strongly Disagree, 5 = Strongly Agree)")
        plt.ylabel("Count")
        plt.xticks(range(1, 6))

        # Annotate each bar with percentage
        for bar in bars:
            height = bar.get_height()
            percent = f"{height / total * 100:.1f}%"
            plt.text(bar.get_x() + bar.get_width() / 2, height, percent, ha='center', va='bottom', fontsize=10)

        # Add horizontal lines for each integer value on the y-axis
        y_min, y_max = plt.gca().get_ylim()
        for y in range(int(y_min), int(y_max) + 1):
            plt.axhline(y, color='gray', linestyle='--', linewidth=0.5, alpha=0.5)

        plt.show()

# %% [markdown]
# ### Step 3.2: Rank Snippets Based on Average Ratings
#
# In this step, we will calculate the average ratings for each snippet across all questions. We will then rank the snippets based on these average ratings to identify the "Fantastic Four" snippets that we will use in the main Prolific study.

# %%
# Step 3.2: Calculate mean rating for each question for each code+error snippet, displaying each question only once
question_names = snippets['snippet_1'].columns[:4]
mean_ratings = {q: [] for q in question_names}
snippet_labels = []
for snippet_name, snippet_df in snippets.items():
    snippet_labels.append(snippet_name)
    for i, q in enumerate(question_names):
        mean_ratings[q].append(pd.to_numeric(snippet_df.iloc[:, i], errors='coerce').dropna().mean())
mean_ratings_df = pd.DataFrame(mean_ratings, index=snippet_labels)
mean_ratings_df.index.name = 'Snippet'
mean_ratings_df.columns.name = 'Question'

print("Mean Ratings for Each Question (columns) and Each Snippet (rows):")
print(mean_ratings_df)
# Out:
# Mean Ratings for Each Question (columns) and Each Snippet (rows):
# Question   This code snippet is difficult to understand.  \
# Snippet
# snippet_1                                       1.785714
# snippet_2                                       1.642857
# snippet_3                                       1.357143
# snippet_4                                       1.571429
# snippet_5                                       1.714286
# snippet_6                                       1.500000
# snippet_7                                       1.500000
# snippet_8                                       2.214286
#
# Question   I would find it challenging to resolve the issue in this code snippet.  \
# Snippet
# snippet_1                                           1.500000
# snippet_2                                           1.285714
# snippet_3                                           1.785714
# snippet_4                                           1.500000
# snippet_5                                           2.642857
# snippet_6                                           1.571429
# snippet_7                                           2.000000
# snippet_8                                           2.500000
#
# Question   Reading this error message feels mentally demanding.  \
# Snippet
# snippet_1                                           2.071429
# snippet_2                                           1.285714
# snippet_3                                           1.714286
# snippet_4                                           2.357143
# snippet_5                                           2.357143
# snippet_6                                           1.785714
# snippet_7                                           2.142857
# snippet_8                                           2.500000
#
# Question   This error message is useful for identifying the problem.
# Snippet
# snippet_1                                           2.928571
# snippet_2                                           4.714286
# snippet_3                                           4.000000
# snippet_4                                           4.214286
# snippet_5                                           2.785714
# snippet_6                                           4.000000
# snippet_7                                           3.928571
# snippet_8                                           3.642857

# %% [markdown]
# ### Step 3.3: Rank Snippets Based on Mean Ratings

# %%
# Step 3.3: For each question, print the snippets ordered ascendingly by their mean rating
for question in mean_ratings_df.columns:
    print(f"\nRanking for question: {question}")
    ranked_snippets = mean_ratings_df[question].sort_values(ascending=True)
    print(ranked_snippets)
# Out:
# Ranking for question: This code snippet is difficult to understand.
# Snippet
# snippet_3    1.357143
# snippet_6    1.500000
# snippet_7    1.500000
# snippet_4    1.571429
# snippet_2    1.642857
# snippet_5    1.714286
# snippet_1    1.785714
# snippet_8    2.214286
# Name: This code snippet is difficult to understand., dtype: float64
#
# Ranking for question: I would find it challenging to resolve the issue in this code snippet.
# Snippet
# snippet_2    1.285714
# snippet_1    1.500000
# snippet_4    1.500000
# snippet_6    1.571429
# snippet_3    1.785714
# snippet_7    2.000000
# snippet_8    2.500000
# snippet_5    2.642857
# Name: I would find it challenging to resolve the issue in this code snippet., dtype: float64
#
# Ranking for question: Reading this error message feels mentally demanding.
# Snippet
# snippet_2    1.285714
# snippet_3    1.714286
# snippet_6    1.785714
# snippet_1    2.071429
# snippet_7    2.142857
# snippet_4    2.357143
# snippet_5    2.357143
# snippet_8    2.500000
# Name: Reading this error message feels mentally demanding., dtype: float64
#
# Ranking for question: This error message is useful for identifying the problem.
# Snippet
# snippet_5    2.785714
# snippet_1    2.928571
# snippet_8    3.642857
# snippet_7    3.928571
# snippet_3    4.000000
# snippet_6    4.000000
# snippet_4    4.214286
# snippet_2    4.714286
# Name: This error message is useful for identifying the problem., dtype: float64

# %% [markdown]
# ### Step 3.4: Plot the Mean Ratings for Each Snippet

# %%
import matplotlib.pyplot as plt

# Plot the mean ratings for each snippet
mean_ratings_df.plot(kind='bar', figsize=(12, 6))
plt.title("Mean Ratings for Each Snippet Across Questions - Convenience Sampling")
plt.xlabel("Snippet")
plt.ylabel("Mean Rating")
plt.ylim(1, 5)
plt.xticks(rotation=45)
plt.tight_layout()

# Place the legend outside the plot
plt.legend(title="Question", bbox_to_anchor=(1.05, 1), loc='upper left')

# Add horizontal lines for each integer value on the y-axis
min_y = int(mean_ratings_df.min().min())
max_y = int(mean_ratings_df.max().max())
for y in range(min_y, max_y + 1):
    plt.axhline(y, color='gray', linestyle='--', linewidth=0.5, alpha=0.5)

plt.show()
